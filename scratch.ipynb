# %%
import numpy as np 

games = np.load('az_games.tmp.npy', allow_pickle=True)

# %%
from viz_board import viz_board

# filter to show like 8 columns, one for each games
# show all the pos 0s on one row 
# all the pos 1s on the next row 
# etc.
